# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
def read_file(filename):
    img=cv2.imread(filename)
    
    plt.imshow(img)
    plt.show()
    return img

# %%
filename="image.jpg"
read_file(filename)
# Out:
# array([[[248, 233, 224],
#         [248, 233, 224],
#         [248, 234, 222],
#         ...,
#         [233, 214,   3],
#         [233, 214,   3],
#         [233, 214,   3]],
#
#        [[248, 233, 224],
#         [248, 233, 224],
#         [248, 234, 222],
#         ...,
#         [232, 213,   2],
#         [233, 214,   3],
#         [232, 213,   2]],
#
#        [[248, 233, 224],
#         [248, 233, 224],
#         [248, 233, 224],
#         ...,
#         [232, 213,   2],
#         [232, 213,   2],
#         [232, 213,   2]],
#
#        ...,
#
#        [[ 81,  71, 147],
#         [ 85,  75, 145],
#         [ 90,  83, 140],
#         ...,
#         [111, 138, 152],
#         [109, 138, 152],
#         [107, 136, 150]],
#
#        [[ 80,  70, 147],
#         [ 84,  73, 145],
#         [ 90,  81, 137],
#         ...,
#         [114, 141, 155],
#         [113, 140, 154],
#         [112, 140, 151]],
#
#        [[ 73,  62, 142],
#         [ 78,  67, 139],
#         [ 88,  79, 135],
# ...
